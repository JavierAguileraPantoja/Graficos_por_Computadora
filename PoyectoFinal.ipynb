# %%
import pygame 
import random 
import time
from random import choice, randrange
from random import randint
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.init()
alto=625
ancho=750
fon=(ancho,alto)
entorno=pygame.display.set_mode((ancho,alto))
pygame.display.set_caption('Ping boll Proyecto Final')


#----------------------------------------------------------------------
#aqui metemos todas las imagenes que usaremos como sonidos y de mas
#Aqui es el fondo en movimiento
fondo1=pygame.image.load("img\\fondo2\\frame-1.gif")
fondo2=pygame.image.load("img\\fondo2\\frame-2.gif")
fondo3=pygame.image.load("img\\fondo2\\frame-3.gif")
fondo4=pygame.image.load("img\\fondo2\\frame-4.gif")
fondo5=pygame.image.load("img\\fondo2\\frame-5.gif")
fondo6=pygame.image.load("img\\fondo2\\frame-6.gif")
fondo7=pygame.image.load("img\\fondo2\\frame-7.gif")
fondo8=pygame.image.load("img\\fondo2\\frame-8.gif")
fondo9=pygame.image.load("img\\fondo2\\frame-9.gif")
fondo10=pygame.image.load("img\\fondo2\\frame-10.gif")
fondo11=pygame.image.load("img\\fondo2\\frame-11.gif")
fondo12=pygame.image.load("img\\fondo2\\frame-12.gif")
fondo13=pygame.image.load("img\\fondo2\\frame-13.gif")
fondo14=pygame.image.load("img\\fondo2\\frame-14.gif")
fondo15=pygame.image.load("img\\fondo2\\frame-15.gif")
fondo16=pygame.image.load("img\\fondo2\\frame-16.gif")
fondo17=pygame.image.load("img\\fondo2\\frame-17.gif")
fondo18=pygame.image.load("img\\fondo2\\frame-18.gif")
fondo19=pygame.image.load("img\\fondo2\\frame-19.gif")
fondo20=pygame.image.load("img\\fondo2\\frame-20.gif")
fondo21=pygame.image.load("img\\fondo2\\frame-21.gif")
fondo22=pygame.image.load("img\\fondo2\\frame-22.gif")
fondo23=pygame.image.load("img\\fondo2\\frame-23.gif")
fondo24=pygame.image.load("img\\fondo2\\frame-24.gif")
fondo25=pygame.image.load("img\\fondo2\\frame-25.gif")
fondo26=pygame.image.load("img\\fondo2\\frame-26.gif")
fondo27=pygame.image.load("img\\fondo2\\frame-27.gif")
fondo28=pygame.image.load("img\\fondo2\\frame-28.gif")
fondo29=pygame.image.load("img\\fondo2\\frame-29.gif")

fondo30=pygame.image.load("img\\fondo2\\frame-30.gif")
fondo31=pygame.image.load("img\\fondo2\\frame-31.gif")
fondo32=pygame.image.load("img\\fondo2\\frame-32.gif")
fondo33=pygame.image.load("img\\fondo2\\frame-33.gif")
fondo34=pygame.image.load("img\\fondo2\\frame-34.gif")
fondo35=pygame.image.load("img\\fondo2\\frame-35.gif")
fondo36=pygame.image.load("img\\fondo2\\frame-36.gif")
fondo37=pygame.image.load("img\\fondo2\\frame-37.gif")
fondo38=pygame.image.load("img\\fondo2\\frame-38.gif")
fondo39=pygame.image.load("img\\fondo2\\frame-39.gif")

fondo40=pygame.image.load("img\\fondo2\\frame-40.gif")
fondo41=pygame.image.load("img\\fondo2\\frame-41.gif")
fondo42=pygame.image.load("img\\fondo2\\frame-42.gif")
fondo43=pygame.image.load("img\\fondo2\\frame-43.gif")
fondo44=pygame.image.load("img\\fondo2\\frame-44.gif")
fondo45=pygame.image.load("img\\fondo2\\frame-45.gif")
fondo46=pygame.image.load("img\\fondo2\\frame-46.gif")
fondo47=pygame.image.load("img\\fondo2\\frame-47.gif")
fondo48=pygame.image.load("img\\fondo2\\frame-48.gif")
fondo49=pygame.image.load("img\\fondo2\\frame-49.gif")

fondo50=pygame.image.load("img\\fondo2\\frame-50.gif")
fondo51=pygame.image.load("img\\fondo2\\frame-51.gif")
fondo52=pygame.image.load("img\\fondo2\\frame-52.gif")
fondo53=pygame.image.load("img\\fondo2\\frame-53.gif")
fondo54=pygame.image.load("img\\fondo2\\frame-54.gif")
fondo55=pygame.image.load("img\\fondo2\\frame-55.gif")
fondo56=pygame.image.load("img\\fondo2\\frame-56.gif")
fondo57=pygame.image.load("img\\fondo2\\frame-57.gif")
fondo58=pygame.image.load("img\\fondo2\\frame-58.gif")
fondo59=pygame.image.load("img\\fondo2\\frame-59.gif")

fondo60=pygame.image.load("img\\fondo2\\frame-60.gif")
fondo61=pygame.image.load("img\\fondo2\\frame-61.gif")
fondo62=pygame.image.load("img\\fondo2\\frame-62.gif")
fondo63=pygame.image.load("img\\fondo2\\frame-63.gif")
fondo64=pygame.image.load("img\\fondo2\\frame-64.gif")
fondo65=pygame.image.load("img\\fondo2\\frame-65.gif")
fondo66=pygame.image.load("img\\fondo2\\frame-66.gif")
fondo67=pygame.image.load("img\\fondo2\\frame-67.gif")
fondo68=pygame.image.load("img\\fondo2\\frame-68.gif")
fondo69=pygame.image.load("img\\fondo2\\frame-69.gif")

fondo70=pygame.image.load("img\\fondo2\\frame-70.gif")
fondo71=pygame.image.load("img\\fondo2\\frame-71.gif")
fondo72=pygame.image.load("img\\fondo2\\frame-72.gif")
fondo73=pygame.image.load("img\\fondo2\\frame-73.gif")
fondo74=pygame.image.load("img\\fondo2\\frame-74.gif")
fondo75=pygame.image.load("img\\fondo2\\frame-75.gif")
fondo76=pygame.image.load("img\\fondo2\\frame-76.gif")
fondo77=pygame.image.load("img\\fondo2\\frame-77.gif")
fondo78=pygame.image.load("img\\fondo2\\frame-78.gif")
fondo79=pygame.image.load("img\\fondo2\\frame-79.gif")

fondo80=pygame.image.load("img\\fondo2\\frame-80.gif")
fondo81=pygame.image.load("img\\fondo2\\frame-81.gif")
fondo82=pygame.image.load("img\\fondo2\\frame-82.gif")
fondo83=pygame.image.load("img\\fondo2\\frame-83.gif")
fondo84=pygame.image.load("img\\fondo2\\frame-84.gif")
fondo85=pygame.image.load("img\\fondo2\\frame-85.gif")
fondo86=pygame.image.load("img\\fondo2\\frame-86.gif")
fondo87=pygame.image.load("img\\fondo2\\frame-87.gif")
fondo88=pygame.image.load("img\\fondo2\\frame-88.gif")
fondo89=pygame.image.load("img\\fondo2\\frame-89.gif")

fondo90=pygame.image.load("img\\fondo2\\frame-90.gif")
fondo91=pygame.image.load("img\\fondo2\\frame-91.gif")
fondo92=pygame.image.load("img\\fondo2\\frame-92.gif")
fondo93=pygame.image.load("img\\fondo2\\frame-93.gif")
fondo94=pygame.image.load("img\\fondo2\\frame-94.gif")
fondo95=pygame.image.load("img\\fondo2\\frame-95.gif")
fondo96=pygame.image.load("img\\fondo2\\frame-96.gif")
fondo97=pygame.image.load("img\\fondo2\\frame-97.gif")
fondo98=pygame.image.load("img\\fondo2\\frame-98.gif")
fondo99=pygame.image.load("img\\fondo2\\frame-99.gif")

fondo100=pygame.image.load("img\\fondo2\\frame-100.gif")
fondo101=pygame.image.load("img\\fondo2\\frame-101.gif")
fondo102=pygame.image.load("img\\fondo2\\frame-102.gif")
fondo103=pygame.image.load("img\\fondo2\\frame-103.gif")
fondo104=pygame.image.load("img\\fondo2\\frame-104.gif")
fondo105=pygame.image.load("img\\fondo2\\frame-105.gif")
fondo106=pygame.image.load("img\\fondo2\\frame-106.gif")
fondo107=pygame.image.load("img\\fondo2\\frame-107.gif")
fondo108=pygame.image.load("img\\fondo2\\frame-108.gif")
fondo109=pygame.image.load("img\\fondo2\\frame-109.gif")

fondo110=pygame.image.load("img\\fondo2\\frame-110.gif")
fondo111=pygame.image.load("img\\fondo2\\frame-111.gif")
fondo112=pygame.image.load("img\\fondo2\\frame-112.gif")
fondo113=pygame.image.load("img\\fondo2\\frame-113.gif")
fondo114=pygame.image.load("img\\fondo2\\frame-114.gif")
fondo115=pygame.image.load("img\\fondo2\\frame-115.gif")
fondo116=pygame.image.load("img\\fondo2\\frame-116.gif")
fondo117=pygame.image.load("img\\fondo2\\frame-117.gif")
fondo118=pygame.image.load("img\\fondo2\\frame-118.gif")
fondo119=pygame.image.load("img\\fondo2\\frame-119.gif")

fondo120=pygame.image.load("img\\fondo2\\frame-120.gif")
fondo121=pygame.image.load("img\\fondo2\\frame-121.gif")


imagenes=[fondo1,fondo2,fondo3,fondo4,fondo5,fondo6,fondo7,fondo8,fondo9,fondo10,fondo11,fondo12,fondo13,fondo14,fondo15,fondo16,fondo17,fondo18,fondo19,fondo20,fondo21,fondo22,fondo23,fondo24,fondo25,fondo26,fondo27,fondo28,fondo29,fondo30,fondo31,fondo32,fondo33,fondo34,fondo35,fondo36,fondo37,fondo38,fondo39,fondo40,fondo41,fondo42,fondo43,fondo44,fondo45,fondo46,fondo47,fondo48,fondo49,fondo50,fondo51,fondo52,fondo53,fondo54,fondo55,fondo56,fondo57,fondo58,fondo59,fondo60,fondo61,fondo62,fondo63,fondo64,fondo65,fondo66,fondo67,fondo68,fondo69,fondo70,fondo71,fondo72,fondo73,fondo74,fondo75,fondo76,fondo77,fondo78,fondo79,fondo80,fondo81,fondo82,fondo83,fondo84,fondo85,fondo86,fondo87,fondo88,fondo89,fondo90,fondo91,fondo92,fondo93,fondo94,fondo95,fondo96,fondo97,fondo98,fondo99,fondo100,fondo101,fondo102,fondo103,fondo104,fondo105,fondo106,fondo107,fondo108,fondo109,fondo110,fondo111,fondo112,fondo113,fondo114,fondo115,fondo116,fondo117,fondo118,fondo119,fondo120,fondo121]

#La mera base tomada de una barberia
bases=pygame.image.load("img\\base.png")

#Definimos la fuenta dde las letras
fuente=pygame.font.Font("freesansbold.ttf",30)

#Sonido en el fondo 
sonidofondo=pygame.mixer.Sound("img\\dark-strings-music-01-57080.mp3")
#sonido de balajugador1
sonidoroto=pygame.mixer.Sound("img\\dulce_roto.mp3")

#importaciones de las naves buenas y la pelota
#Dulces
dulce_rojo=pygame.image.load("img\\dulce_rojo.png")
dulce_verde=pygame.image.load("img\\dulce _verde.png")
dulce_menta=pygame.image.load("img\\dulce_azul.png")
dulce_baston=pygame.image.load("img\\dulce_baston.png")
dulce_mono=pygame.image.load("img\\dulce_mono.png")
#Pelota numero uno
pelota=pygame.image.load("img\\bola.png")

#----------------------------------------------------------------------------------------

#Acomodamos sus tamños de los dulces y bola y la base
bola=pygame.transform.scale(pelota,(70,70))
dr=pygame.transform.scale(dulce_rojo,(70,70))
dm=pygame.transform.scale(dulce_menta,(70,70))
dv=pygame.transform.scale(dulce_verde,(70,70))
db=pygame.transform.scale(dulce_baston,(70,70))
dmo=pygame.transform.scale(dulce_mono,(70,70))
base=pygame.transform.scale(bases,(200,50))

#------------------------------------------------------------------------------------------
#-------------------------- Declaracion de reloj-------------------------------------------
clock=pygame.time.Clock()
#------------------------------------------------------------------------------------------
#--------------------------------texto a poner---------------------------------------------
title_font=pygame.font.SysFont("arial",50)
title_label=title_font.render("Preciona Espacio y continuaremos de nuevo...",1,(255,255,255))
#
#variables necesaria para el jale
l=0 #controlador de imagens
vidas=3
score=0
#---------variables que indica la posicion de inicio del objeto y su velocidadx de movimiento
dx=ancho/2-100
dy=alto-50
movlateral=10
#---------variables que indicar la psoicion de inicio de bola  la velocidad de movimiento
dxx=ancho/2-35
dyy=alto-95
vxx=randint(3,12)
vyy=randint(3,12)
#---------------Variables que indican la posicion de inicio de los dulces
dxxx=0
dyyy=0
#------------------------------ Variables de ayuda
espacioy=-60
a=0
l=0
x=100
y=100
#-----------------------------------------------------------------------------------------
#------------------------- Las clases y funciones -----------------------------------------

class objetos:
  def __init__(self,x,y,salud=100):
    self.x=x
    self.y=y
    self.salud=salud
    self.image=None
  def dibujar(self,entorno):
    entorno.blit(self.image,(self.x,self.y))
  
 
class Jugador(objetos):
  def __init__(self,x,y,salud=100):
    super().__init__(x,y,salud)
    self.image=base
    self.mask=pygame.mask.from_surface(self.image)
    
    
#clase de la bola heredando de clase padre objetos   
class Bola(objetos):
  def __init__(self,x,y):
    super().__init__(x,y)
    self.image=bola
    self.mask=pygame.mask.from_surface(self.image)
    self.x=x
    self.y=y
    #if(Bola.colliderect(Jugador)):
     # self.y*=-1

    
  def bolainicio(self):
    #que aparesca as perdido una vida preciona space 
    #que comience de nuevo
    self.x=dxx
    self.y=dyy
    #que reste una vida

    
  def movimiento(self):
    global vxx,vyy
    self.x-=vxx
    self.y-=vyy

    if(self.x>=(ancho-45)):
      vxx=-vxx        
    if(self.y>=(alto-60)):
      vyy=-vyy
      self.bolainicio()
    if(self.x<=(-20)):
      vxx=-(vxx)
    if(self.y<=(-15)):
      vyy=-(vyy)
  
     
     
    
    
class Dulces(objetos):
  def __init__(self, x, y, salud=100):
    super().__init__(x, y, salud)
    self.x
    self.y    
    self.image = random.choice([(dr),(dm),(dv)])
    self.mask=pygame.mask.from_surface(self.image)
  
  def movimiento(self):
    
    self.y+=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 12
#       6 pygame.display.set_caption('Ping boll Proyecto Final')
#       9 #----------------------------------------------------------------------
#      10 #aqui metemos todas las imagenes que usaremos como sonidos y de mas
#      11 #Aqui es el fondo en movimiento
# ---> 12 fondo1=pygame.image.load("img\\fondo2\\frame-1.gif")
#      13 fondo2=pygame.image.load("img\\fondo2\\frame-2.gif")
#      14 fondo3=pygame.image.load("img\\fondo2\\frame-3.gif")
#
# FileNotFoundError: No file 'img\fondo2\frame-1.gif' found in working directory 'c:\Users\javie\OneDrive\Escritorio\Graficos_por_Computadora'.
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
# ...

# %%
  
#----------------------------------Declaracion de los objetos------------------------------
jugador=Jugador(dx,dy)
bola1=Bola(dxx,dyy)  
dulce=Dulces(dxxx,dyyy)

#--------------------------------------creacion de enmigos------------------------------------
enemigos=[]
numero_enemigos=10
for i in range(numero_enemigos):
  enemi=Dulces(dxxx,dyyy)
  enemigos.append(enemi)
  dxxx+=75
  

#------------------------------------El while en el mero climas la funcion de proyeccion en la pantalla----------------------------
def main():
  a=0
  
  
  bandera=True
  while bandera:
    sonidofondo.play()
    for evento in pygame.event.get():
      if(evento.type==pygame.QUIT):
        bandera=False
		#dibujar fondo-----------------------------------
    if(a>=121):
      a=0
    fondo=pygame.transform.scale(imagenes[a],(fon))
    a+=1
    entorno.blit(fondo,(0,0))
    #-----------------------------------------
    jugador.dibujar(entorno)
    bola1.dibujar(entorno)
    dulce.dibujar(entorno)
    dulce.movimiento()
    bola1.movimiento()
    key=pygame.key.get_pressed()
    if(key[pygame.K_LEFT]):
      if(jugador.x <=-8):
        jugador.x += movlateral
      else:
        jugador.x -= movlateral
    elif(key[pygame.K_RIGHT]):
      if(jugador.x>=(ancho-192)):
        jugador.x -= movlateral
      else:
        jugador.x += movlateral
    #letras 
    texto1=fuente.render(f"Score: {score}",True,(255,255,255))
    entorno.blit(texto1,(600,0))
    texto2=fuente.render(f"Lives: {vidas}",True,(255,255,255))
    entorno.blit(texto2,(0,0))
    #fin del juego
    pygame.display.update()
    pygame.time.Clock().tick(60)
  pygame.quit()
 
main()
